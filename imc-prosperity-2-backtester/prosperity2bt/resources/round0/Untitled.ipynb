# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("prices_round_0_day_-1.csv", delimiter = ";")

# %%
df["profit_and_loss"] = 0.0 
df["day"] = -2
df = df.fillna("")

# %%
df
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1 bid_price_2  \
# 0      -2          0  RAINFOREST_RESIN        10002             1      9996.0
# 1      -2          0              KELP         2028             1      2026.0
# 2      -2        100              KELP         2025            24
# 3      -2        100  RAINFOREST_RESIN         9996             2      9995.0
# 4      -2        200  RAINFOREST_RESIN         9995            20
# ...   ...        ...               ...          ...           ...         ...
# 3995   -2     199700              KELP         2020            27
# 3996   -2     199800  RAINFOREST_RESIN         9995            21
# 3997   -2     199800              KELP         2020            21
# 3998   -2     199900              KELP         2020            32
# 3999   -2     199900  RAINFOREST_RESIN         9996             2      9995.0
#
#      bid_volume_2 bid_price_3 bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df_single = df.astype(str).agg(";".join, axis=1).to_frame(name="merged")

# %%
data_rows = df.astype(str).agg(";".join, axis=1)

# Convert header to a string
header_row = ";".join(df.columns)

# Combine header and data into one list
all_rows = [header_row] + data_rows.tolist()

# Save to CSV (4000x1 style with semicolon delimiter)
with open("output.csv", "w") as f:
    for row in all_rows:
        f.write(row + "\n")

# %%
#df_single.to_csv("output.csv", index=False)
