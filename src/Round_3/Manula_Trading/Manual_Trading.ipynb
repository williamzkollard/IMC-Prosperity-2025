# %% [markdown]
# # Imports

# %%
import math
import numpy as np

# %% [markdown]
# # Solution of past year

# %% [markdown]
# We solve this problem:
#
# $( p_l, p_h) \mapsto
# (320 - p_l) \int_{160}^{p_l} (\alpha r + \beta) \, dr
# + (320 - p_h) \int_{p_l}^{p_h} (\alpha r + \beta) \, dr
# \left(
#     \mathbb{1}_{\bar{p} \leq p_h} +
#     \mathbb{1}_{\bar{p} > p_h} \cdot
#     \frac{320 - \bar{p}}{320 - p_h}
# \right). $
#
#
# Note that:
#
# $\int_{a}^{b} (\alpha r + \beta)\,dr
# = -\frac{\alpha}{2}\bigl(b^2 - a^2\bigr) + \beta\,(b - a). $

# %%
def solve(p_avg):
    """
    Given the average of second bids, find the optimal low and high bids,
    using an integration interval that starts at 160 instead of 260.

    Parameters
    ----------
    p_avg : float
        Average value of second bids.

    Returns
    -------
    argmax : list of tuple
        Maximizers.
    val_max : float
        Maximal profit.
    """
    val_max = float('-inf')
    argmax = []


    # (You may also wish to adjust these bounds for your particular problem.)
    for l in range(160, 320):
        for h in range(l, 320):
            temp = (320 - l) * (-(4/103) * (-160 + l) + (-12800 + l**2/2)) / 5150
            temp2 = (320 - h) * (-(4/103) * (h - l) + (h**2/2 - l**2/2)) / 5150
            val = temp + temp2 * (1 if p_avg <= h else (320-p_avg)/(320-h))

            if math.isclose(val, val_max):
                argmax.append((l, h, val))
            if val > val_max:
                val_max = val
                argmax = [(l, h)]
    return argmax, val_max

# %%
for p_avg in np.arange(250,320,0.5):
    argmax, val_max = solve(p_avg)
    if len(argmax) > 1:
        print("p_avg:", p_avg, "  Maximizers:", argmax, " Profit:", f"{val_max:.2f}")
    else:
        print("p_avg:", p_avg, "  Maximizer:", argmax[0], " Profit:", f"{val_max:.2f}")
# Out:
# p_avg: 250.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 250.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 251.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 251.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 252.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 252.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 253.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 253.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 254.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 254.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 255.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 255.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 256.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 256.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 257.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 257.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 258.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 258.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 259.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 259.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 260.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 260.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 261.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 261.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 262.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 262.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 263.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 263.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 264.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 264.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 265.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 265.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 266.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 266.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 267.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 267.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 268.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 268.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 269.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 269.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 270.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 270.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 271.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 271.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 272.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 272.5   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 273.0   Maximizer: (221, 273)  Profit: 340.54
# p_avg: 273.5   Maximizer: (221, 274)  Profit: 340.49
# p_avg: 274.0   Maximizer: (221, 274)  Profit: 340.49
# p_avg: 274.5   Maximizer: (222, 275)  Profit: 340.36
# p_avg: 275.0   Maximizer: (222, 275)  Profit: 340.36
# p_avg: 275.5   Maximizer: (222, 276)  Profit: 340.16
# p_avg: 276.0   Maximizer: (222, 276)  Profit: 340.16
# p_avg: 276.5   Maximizer: (223, 277)  Profit: 339.89
# p_avg: 277.0   Maximizer: (223, 277)  Profit: 339.89
# p_avg: 277.5   Maximizer: (224, 278)  Profit: 339.53
# p_avg: 278.0   Maximizer: (224, 278)  Profit: 339.53
# p_avg: 278.5   Maximizer: (224, 279)  Profit: 339.12
# p_avg: 279.0   Maximizer: (224, 279)  Profit: 339.12
# p_avg: 279.5   Maximizer: (225, 280)  Profit: 338.61
# p_avg: 280.0   Maximizer: (225, 280)  Profit: 338.61
# p_avg: 280.5   Maximizer: (225, 281)  Profit: 338.04
# p_avg: 281.0   Maximizer: (225, 281)  Profit: 338.04
# p_avg: 281.5   Maximizer: (226, 282)  Profit: 337.39
# p_avg: 282.0   Maximizer: (226, 282)  Profit: 337.39
# p_avg: 282.5   Maximizer: (226, 283)  Profit: 336.66
# p_avg: 283.0   Maximizer: (226, 283)  Profit: 336.66
# p_avg: 283.5   Maximizer: (227, 284)  Profit: 335.86
# p_avg: 284.0   Maximizer: (227, 284)  Profit: 335.86
# p_avg: 284.5   Maximizer: (228, 285)  Profit: 334.96
# p_avg: 285.0   Maximizer: (228, 285)  Profit: 334.96
# p_avg: 285.5   Maximizer: (228, 286)  Profit: 334.01
# p_avg: 286.0   Maximizer: (228, 286)  Profit: 334.01
# p_avg: 286.5   Maximizer: (229, 287)  Profit: 332.96
# p_avg: 287.0   Maximizer: (229, 287)  Profit: 332.96
# p_avg: 287.5   Maximizer: (229, 288)  Profit: 331.84
# p_avg: 288.0   Maximizer: (229, 288)  Profit: 331.84
# p_avg: 288.5   Maximizer: (230, 289)  Profit: 330.64
# p_avg: 289.0   Maximizer: (230, 289)  Profit: 330.64
# p_avg: 289.5   Maximizer: (230, 290)  Profit: 329.36
# p_avg: 290.0   Maximizer: (230, 290)  Profit: 329.36
# p_avg: 290.5   Maximizer: (231, 291)  Profit: 328.00
# p_avg: 291.0   Maximizer: (231, 291)  Profit: 328.00
# p_avg: 291.5   Maximizer: (232, 292)  Profit: 326.54
# p_avg: 292.0   Maximizer: (232, 292)  Profit: 326.54
# p_avg: 292.5   Maximizer: (232, 293)  Profit: 325.03
# p_avg: 293.0   Maximizer: (232, 293)  Profit: 325.03
# p_avg: 293.5   Maximizer: (232, 293)  Profit: 323.47
# p_avg: 294.0   Maximizer: (233, 294)  Profit: 323.41
# p_avg: 294.5   Maximizer: (233, 294)  Profit: 321.85
# p_avg: 295.0   Maximizer: (233, 295)  Profit: 321.72
# p_avg: 295.5   Maximizer: (234, 295)  Profit: 320.14
# p_avg: 296.0   Maximizer: (234, 296)  Profit: 319.95
# p_avg: 296.5   Maximizer: (234, 296)  Profit: 318.35
# p_avg: 297.0   Maximizer: (234, 297)  Profit: 318.08
# p_avg: 297.5   Maximizer: (235, 297)  Profit: 316.47
# p_avg: 298.0   Maximizer: (235, 298)  Profit: 316.14
# p_avg: 298.5   Maximizer: (235, 298)  Profit: 314.51
# p_avg: 299.0   Maximizer: (236, 299)  Profit: 314.10
# p_avg: 299.5   Maximizer: (236, 299)  Profit: 312.47
# p_avg: 300.0   Maximizer: (236, 300)  Profit: 312.00
# p_avg: 300.5   Maximizer: (236, 300)  Profit: 310.33
# p_avg: 301.0   Maximizer: (237, 301)  Profit: 309.79
# p_avg: 301.5   Maximizer: (237, 301)  Profit: 308.12
# p_avg: 302.0   Maximizer: (237, 302)  Profit: 307.50
# p_avg: 302.5   Maximizer: (238, 302)  Profit: 305.81
# p_avg: 303.0   Maximizer: (238, 303)  Profit: 305.13
# p_avg: 303.5   Maximizer: (238, 303)  Profit: 303.42
# p_avg: 304.0   Maximizer: (238, 304)  Profit: 302.66
# p_avg: 304.5   Maximizer: (239, 304)  Profit: 300.94
# p_avg: 305.0   Maximizer: (239, 305)  Profit: 300.12
# p_avg: 305.5   Maximizer: (239, 305)  Profit: 298.37
# p_avg: 306.0   Maximizer: (240, 306)  Profit: 297.47
# p_avg: 306.5   Maximizer: (240, 306)  Profit: 295.72
# p_avg: 307.0   Maximizer: (240, 307)  Profit: 294.74
# p_avg: 307.5   Maximizer: (240, 307)  Profit: 292.97
# p_avg: 308.0   Maximizer: (241, 308)  Profit: 291.93
# p_avg: 308.5   Maximizer: (241, 308)  Profit: 290.14
# p_avg: 309.0   Maximizer: (241, 309)  Profit: 289.01
# p_avg: 309.5   Maximizer: (242, 309)  Profit: 287.21
# p_avg: 310.0   Maximizer: (242, 310)  Profit: 286.02
# p_avg: 310.5   Maximizer: (242, 310)  Profit: 284.20
# p_avg: 311.0   Maximizer: (243, 311)  Profit: 282.92
# p_avg: 311.5   Maximizer: (243, 311)  Profit: 281.09
# p_avg: 312.0   Maximizer: (243, 312)  Profit: 279.75
# p_avg: 312.5   Maximizer: (243, 312)  Profit: 277.89
# p_avg: 313.0   Maximizer: (244, 313)  Profit: 276.47
# p_avg: 313.5   Maximizer: (244, 313)  Profit: 274.60
# p_avg: 314.0   Maximizer: (244, 314)  Profit: 273.10
# p_avg: 314.5   Maximizer: (245, 314)  Profit: 271.21
# p_avg: 315.0   Maximizer: (245, 315)  Profit: 269.65
# p_avg: 315.5   Maximizer: (245, 315)  Profit: 267.74
# p_avg: 316.0   Maximizer: (245, 316)  Profit: 266.09
# p_avg: 316.5   Maximizer: (246, 316)  Profit: 264.17
# p_avg: 317.0   Maximizer: (246, 317)  Profit: 262.45
# p_avg: 317.5   Maximizer: (246, 317)  Profit: 260.51
# p_avg: 318.0   Maximizer: (247, 318)  Profit: 258.70
# p_avg: 318.5   Maximizer: (247, 318)  Profit: 256.75
# p_avg: 319.0   Maximizer: (247, 319)  Profit: 254.87
# p_avg: 319.5   Maximizer: (247, 319)  Profit: 252.89

# %% [markdown]
# # Simulation on expected profits computed from uniform distribution

# %%
# -----------------------------------------------------------
# Function: sample_reserve
# -----------------------------------------------------------
def sample_reserve(r_config, size):
    """
    Samples Turtle reserve prices from a disjoint, piecewise uniform distribution.

    Parameters:
      r_config : tuple
          Defines the two intervals for the reserve price.
          Example: (160, 200, 250, 320) means reserve is uniformly drawn
          from [160,200] or from [250,320].
      size : int
          Number of random samples to generate.

    Returns:
      samples : np.array
          Array of reserve price samples.
    """
    # Unpack the intervals
    r1_low, r1_high, r2_low, r2_high = r_config
    # Compute the lengths of the two intervals
    L1 = r1_high - r1_low
    L2 = r2_high - r2_low
    total_length = L1 + L2
    # Decide for each sample whether to draw from interval 1 or 2
    u = np.random.uniform(0, 1, size)
    samples = np.empty(size)
    idx1 = u < (L1 / total_length)  # proportion from the first interval
    n1 = np.sum(idx1)
    n2 = size - n1
    samples[idx1] = np.random.uniform(r1_low, r1_high, n1)
    samples[~idx1] = np.random.uniform(r2_low, r2_high, n2)
    return samples

# -----------------------------------------------------------
# Function: simulate_profit
# -----------------------------------------------------------
def simulate_profit(b1, b2, A, r_config, selling_price=320, N=10000):
    """
    Simulates the average profit for given bid levels (b1 and b2) and
    average competitor bid A, under the new rule:

      - Round 1:
          If the Turtle's reserve r ≤ b1, it accepts
          and profit = selling_price - b1.
      - Round 2:
          * If b2 > A and r < b2, profit = selling_price - b2.
          * If b2 < A and r < b2, profit = (selling_price - b2) * p,
            where p = ((selling_price - A)**3)/(selling_price - b2).
          (No profit if r ≥ b2.)

    Parameters
    ----------
    b1 : float
        First-round bid.
    b2 : float
        Second-round bid (should satisfy b2 >= b1).
    A : float
        Average competitor second bid.
    r_config : tuple
        Defines intervals for the reserve price distribution, e.g. (160,200,250,320).
    selling_price : float, optional
        Price at which you resell the item (default = 320).
    N : int, optional
        Number of Monte Carlo samples (default = 10000).

    Returns
    -------
    avg_profit : float
        Average profit over N simulated draws from the piecewise reserve distribution.
    """
    # 1) Draw N Turtle reserve prices from disjoint intervals
    reserves = sample_reserve(r_config, N)

    # 2) Initialize profit array
    profits = np.zeros(N)

    # 3) Round 1: If reserve ≤ b1, you get the Flipper for b1
    round1_success = (reserves <= b1)
    profits[round1_success] = selling_price - b1

    # 4) Round 2: Only for Turtles that didn't accept round 1
    round1_failure = ~round1_success

    # Case A: b2 > A → normal acceptance if r < b2
    round2_success_above = round1_failure & (b2 > A) & (reserves < b2)
    profits[round2_success_above] = selling_price - b2

    # Case B: b2 < A → scaled acceptance if r < b2
    round2_success_below = round1_failure & (b2 < A) & (reserves < b2)
    if b2 < selling_price:  # To avoid any division by zero if b2 == 320
        scale_factor = ((selling_price - A) / (selling_price - b2))**3
        profits[round2_success_below] = (selling_price - b2) * scale_factor

    # 5) Average profit over all samples
    return np.mean(profits)

# -----------------------------------------------------------
# Function: optimize_strategy
# -----------------------------------------------------------
def optimize_strategy(A, r_config, selling_price=320,
                      b1_min=160, b1_max=320, b2_min=160, b2_max=320,
                      step=1, N=10000):
    """
    Searches over first and second bid pairs (b1 and b2) to find the pair
    that maximizes the average profit, given an average competitor bid A and
    a Turtle reserve distribution defined by r_config.

    Parameters:
      A : int or float
          The average competitor second bid.
      r_config : tuple
          Reserve price configuration (e.g., (160,200,250,320)).
      selling_price : int or float, default=320
      b1_min, b1_max : int
          The allowable range for the first bid.
      b2_min, b2_max : int
          The allowable range for the second bid.
      step : int
          The discretization step for the grid search.
      N : int
          Number of Monte Carlo samples for each bid pair evaluation.

    Returns:
      best_b1, best_b2 : optimal first and second bid values found.
      best_profit : The corresponding average simulated profit.
    """
    best_profit = -np.inf
    best_b1, best_b2 = None, None

    # Loop over all candidate bids for first and second rounds.
    for b1 in range(b1_min, b1_max + 1, step):
        for b2 in range(b1, b2_max + 1, step):  # Enforce b2 >= b1.
            profit = simulate_profit(b1, b2, A, r_config, selling_price, N)
            if profit > best_profit:
                best_profit = profit
                best_b1, best_b2 = b1, b2

    return best_b1, best_b2, best_profit

# -----------------------------------------------------------
# Main simulation: Varying A and reserve parameters (r_config)
# -----------------------------------------------------------
if __name__ == '__main__':
    # Reserve distribution configurations can be stored in a dictionary.
    r_configs = {
        "config1": (160, 200, 250, 320),    # Original configuration.
    }

    # Define a range of average competitor second bids A.
    A_values = np.arange(160, 321, 5)  # For example, from 160 to 320 in steps of 20.

    # Dictionary to store results for each configuration.
    results = {}

    for config_name, r_config in r_configs.items():
        config_results = []
        print(f"\n--- Results for {config_name} ---")
        for A in A_values:
            b1_opt, b2_opt, profit_opt = optimize_strategy(A, r_config, N=5000, step=1)
            config_results.append((A, b1_opt, b2_opt, profit_opt))
            print(f"Average competitor bid A={A:3d} => Optimal b1={b1_opt:3d}, b2={b2_opt:3d} with profit={profit_opt:7.2f}")
        results[config_name] = config_results
# Out:
# --- Results for config1 ---
# Average competitor bid A=160 => Optimal b1=200, b2=285 with profit=  55.62
# Average competitor bid A=165 => Optimal b1=198, b2=284 with profit=  56.26
# Average competitor bid A=170 => Optimal b1=200, b2=283 with profit=  55.73
# Average competitor bid A=175 => Optimal b1=200, b2=286 with profit=  55.94
# Average competitor bid A=180 => Optimal b1=201, b2=280 with profit=  55.68
# Average competitor bid A=185 => Optimal b1=201, b2=287 with profit=  55.88
# Average competitor bid A=190 => Optimal b1=200, b2=290 with profit=  55.95
# Average competitor bid A=195 => Optimal b1=200, b2=291 with profit=  55.69
# Average competitor bid A=200 => Optimal b1=200, b2=281 with profit=  56.15
# Average competitor bid A=205 => Optimal b1=200, b2=282 with profit=  56.04
# Average competitor bid A=210 => Optimal b1=200, b2=277 with profit=  56.38
# Average competitor bid A=215 => Optimal b1=200, b2=279 with profit=  56.31
# Average competitor bid A=220 => Optimal b1=199, b2=281 with profit=  56.18
# Average competitor bid A=225 => Optimal b1=200, b2=292 with profit=  55.93
# Average competitor bid A=230 => Optimal b1=200, b2=283 with profit=  56.06
# Average competitor bid A=235 => Optimal b1=200, b2=284 with profit=  56.62
# Average competitor bid A=240 => Optimal b1=199, b2=278 with profit=  56.15
# Average competitor bid A=245 => Optimal b1=200, b2=287 with profit=  56.24
# Average competitor bid A=250 => Optimal b1=200, b2=291 with profit=  56.18
# Average competitor bid A=255 => Optimal b1=200, b2=284 with profit=  55.80
# Average competitor bid A=260 => Optimal b1=200, b2=277 with profit=  55.69
# Average competitor bid A=265 => Optimal b1=202, b2=284 with profit=  55.92
# Average competitor bid A=270 => Optimal b1=199, b2=288 with profit=  55.55
# Average competitor bid A=275 => Optimal b1=201, b2=286 with profit=  56.16
# Average competitor bid A=280 => Optimal b1=200, b2=284 with profit=  56.46
# Average competitor bid A=285 => Optimal b1=200, b2=287 with profit=  56.14
# Average competitor bid A=290 => Optimal b1=199, b2=291 with profit=  55.09
# Average competitor bid A=295 => Optimal b1=203, b2=297 with profit=  54.25
# Average competitor bid A=300 => Optimal b1=200, b2=303 with profit=  52.77
# Average competitor bid A=305 => Optimal b1=200, b2=307 with profit=  51.71
# Average competitor bid A=310 => Optimal b1=201, b2=313 with profit=  48.93
# Average competitor bid A=315 => Optimal b1=200, b2=316 with profit=  47.16
# Average competitor bid A=320 => Optimal b1=201, b2=228 with profit=  45.84
